# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Create an empty list to hold the weather data. note for the weather description-the double parentheses--json format required it
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | constitucion
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | gazli
# Processing Record 6 of Set 1 | kotelnikovo
# Processing Record 7 of Set 1 | valenca do piaui
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | okha
# Processing Record 10 of Set 1 | lima
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | kibala
# Processing Record 15 of Set 1 | ongandjera
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | liverpool
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | moshenskoye
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | himora
# City not found. Skipping...
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | ixtapa
# Processing Record 25 of Set 1 | pitimbu
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ryotsu
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | viedma
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | contamana
# Processing Record 34 of Set 1 | nizhniy tsasuchey
# Processing Record 35 of Set 1 | hay river
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | lata
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | araguaina
# Processing Record 40 of Set 1 | griffith
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | bend
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | dudinka
# Processing Record 48 of Set 1 | alugan
# Processing Record 49 of Set 1 | urozhayne
# City not found. Skipping...
# Processing Record 50 of Set 1 | ostrovnoy
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | umm lajj
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | adre
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | mitu
# Processing Record 15 of Set 2 | gadsden
# Processing Record 16 of Set 2 | la ronge
# Processing Record 17 of Set 2 | issoire
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | zemio
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | baykit
# Processing Record 24 of Set 2 | haimen
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | buin
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | cheremukhovo
# Processing Record 30 of Set 2 | boulder
# Processing Record 31 of Set 2 | malaya vishera
# Processing Record 32 of Set 2 | tura
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | rjukan
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | yar-sale
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | carutapera
# Processing Record 39 of Set 2 | marzuq
# Processing Record 40 of Set 2 | katobu
# Processing Record 41 of Set 2 | mount isa
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | rakkestad
# Processing Record 44 of Set 2 | ust-ilimsk
# Processing Record 45 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | thunder bay
# Processing Record 49 of Set 2 | vardo
# Processing Record 50 of Set 2 | rottenmann
# Processing Record 1 of Set 3 | qui nhon
# Processing Record 2 of Set 3 | brownsville
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | cozumel
# Processing Record 6 of Set 3 | caiaponia
# Processing Record 7 of Set 3 | minsk
# Processing Record 8 of Set 3 | qostanay
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | bilibino
# Processing Record 11 of Set 3 | broome
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | urumqi
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | isangel
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | mahibadhoo
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | san patricio
# Processing Record 23 of Set 3 | bazpur
# Processing Record 24 of Set 3 | vila
# Processing Record 25 of Set 3 | alofi
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | russell
# Processing Record 30 of Set 3 | karratha
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | matamoros
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | uyuni
# Processing Record 36 of Set 3 | abu samrah
# Processing Record 37 of Set 3 | iquique
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | acapulco
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | ziri
# Processing Record 43 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 3 | araouane
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | moranbah
# Processing Record 47 of Set 3 | srednekolymsk
# Processing Record 48 of Set 3 | manakara
# Processing Record 49 of Set 3 | alexandria
# Processing Record 50 of Set 3 | camacha
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | kalmar
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | ngunguru
# Processing Record 8 of Set 4 | cape town
# Processing Record 9 of Set 4 | noumea
# Processing Record 10 of Set 4 | skibbereen
# Processing Record 11 of Set 4 | ikalamavony
# Processing Record 12 of Set 4 | mahajanga
# Processing Record 13 of Set 4 | taksimo
# Processing Record 14 of Set 4 | high level
# Processing Record 15 of Set 4 | yumen
# Processing Record 16 of Set 4 | ayr
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | troitskoye
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | hobyo
# Processing Record 21 of Set 4 | san quintin
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | teknaf
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | haines junction
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | mongo
# Processing Record 29 of Set 4 | manggar
# Processing Record 30 of Set 4 | meulaboh
# Processing Record 31 of Set 4 | chany
# Processing Record 32 of Set 4 | la rioja
# Processing Record 33 of Set 4 | bima
# Processing Record 34 of Set 4 | thinadhoo
# Processing Record 35 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 4 | kirovskiy
# Processing Record 37 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 38 of Set 4 | kutum
# Processing Record 39 of Set 4 | avera
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | atambua
# Processing Record 44 of Set 4 | tuskegee
# Processing Record 45 of Set 4 | mocuba
# Processing Record 46 of Set 4 | laguna
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | liku
# Processing Record 50 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | novyy urgal
# Processing Record 2 of Set 5 | christchurch
# Processing Record 3 of Set 5 | ocala
# Processing Record 4 of Set 5 | maturin
# Processing Record 5 of Set 5 | khalkhal
# Processing Record 6 of Set 5 | agirish
# Processing Record 7 of Set 5 | purworejo
# Processing Record 8 of Set 5 | miles city
# Processing Record 9 of Set 5 | barra patuca
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | makinsk
# Processing Record 12 of Set 5 | tilichiki
# Processing Record 13 of Set 5 | hervey bay
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | nantucket
# Processing Record 17 of Set 5 | north bend
# Processing Record 18 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 19 of Set 5 | la union
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | yuci
# Processing Record 24 of Set 5 | sobolevo
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | bowen
# Processing Record 28 of Set 5 | kieta
# Processing Record 29 of Set 5 | necochea
# Processing Record 30 of Set 5 | brae
# Processing Record 31 of Set 5 | tongchuan
# Processing Record 32 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 5 | nuevo progreso
# Processing Record 34 of Set 5 | norman wells
# Processing Record 35 of Set 5 | labuhan
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | nouadhibou
# Processing Record 39 of Set 5 | gat
# Processing Record 40 of Set 5 | erdenet
# Processing Record 41 of Set 5 | roebourne
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | port hedland
# Processing Record 44 of Set 5 | hammerfest
# Processing Record 45 of Set 5 | sistranda
# Processing Record 46 of Set 5 | sa kaeo
# Processing Record 47 of Set 5 | goderich
# Processing Record 48 of Set 5 | umm kaddadah
# Processing Record 49 of Set 5 | bambanglipuro
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | banda aceh
# Processing Record 2 of Set 6 | zhigalovo
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | aksarka
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | saint-francois
# Processing Record 9 of Set 6 | doka
# Processing Record 10 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 11 of Set 6 | chapais
# Processing Record 12 of Set 6 | kirando
# Processing Record 13 of Set 6 | coracora
# Processing Record 14 of Set 6 | eskilstuna
# Processing Record 15 of Set 6 | phan thiet
# Processing Record 16 of Set 6 | bongandanga
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | namtsy
# Processing Record 19 of Set 6 | paracatu
# Processing Record 20 of Set 6 | wajima
# Processing Record 21 of Set 6 | coihaique
# Processing Record 22 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 23 of Set 6 | quetzaltepec
# City not found. Skipping...
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | zhangye
# Processing Record 26 of Set 6 | yeppoon
# Processing Record 27 of Set 6 | ahipara
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | marawi
# Processing Record 30 of Set 6 | conde
# Processing Record 31 of Set 6 | xiaoyi
# Processing Record 32 of Set 6 | nampula
# Processing Record 33 of Set 6 | redlands
# Processing Record 34 of Set 6 | naze
# Processing Record 35 of Set 6 | hamadan
# Processing Record 36 of Set 6 | shimoda
# Processing Record 37 of Set 6 | glubczyce
# Processing Record 38 of Set 6 | fairbanks
# Processing Record 39 of Set 6 | kholmogory
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | aquidauana
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 6 | emerald
# Processing Record 46 of Set 6 | durusu
# Processing Record 47 of Set 6 | road town
# Processing Record 48 of Set 6 | olecko
# Processing Record 49 of Set 6 | hashtrud
# Processing Record 50 of Set 6 | hualmay
# Processing Record 1 of Set 7 | ukiah
# Processing Record 2 of Set 7 | yusva
# City not found. Skipping...
# Processing Record 3 of Set 7 | naryan-mar
# Processing Record 4 of Set 7 | tarauaca
# Processing Record 5 of Set 7 | iqaluit
# Processing Record 6 of Set 7 | buchanan
# Processing Record 7 of Set 7 | kralendijk
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | chapleau
# Processing Record 10 of Set 7 | agadir
# Processing Record 11 of Set 7 | skopje
# Processing Record 12 of Set 7 | akyab
# Processing Record 13 of Set 7 | vestmanna
# Processing Record 14 of Set 7 | saint-georges
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | molchanovo
# Processing Record 17 of Set 7 | muisne
# Processing Record 18 of Set 7 | russkaya polyana
# Processing Record 19 of Set 7 | mandalgovi
# Processing Record 20 of Set 7 | agadez
# Processing Record 21 of Set 7 | guerrero negro
# Processing Record 22 of Set 7 | marsh harbour
# Processing Record 23 of Set 7 | hami
# Processing Record 24 of Set 7 | lakes entrance
# Processing Record 25 of Set 7 | de aar
# Processing Record 26 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | samarai
# Processing Record 29 of Set 7 | college
# Processing Record 30 of Set 7 | thompson
# Processing Record 31 of Set 7 | kaeo
# Processing Record 32 of Set 7 | sao francisco
# Processing Record 33 of Set 7 | ambon
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | dabat
# Processing Record 37 of Set 7 | oyon
# Processing Record 38 of Set 7 | salalah
# Processing Record 39 of Set 7 | codrington
# Processing Record 40 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 7 | alcaniz
# Processing Record 42 of Set 7 | bambous virieux
# Processing Record 43 of Set 7 | manzil salim
# Processing Record 44 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | sovetskiy
# Processing Record 47 of Set 7 | grootfontein
# Processing Record 48 of Set 7 | cambyreta
# City not found. Skipping...
# Processing Record 49 of Set 7 | port hardy
# Processing Record 50 of Set 7 | cimislia
# Processing Record 1 of Set 8 | abonnema
# Processing Record 2 of Set 8 | atasu
# Processing Record 3 of Set 8 | fayaoue
# Processing Record 4 of Set 8 | lavrentiya
# Processing Record 5 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | charlestown
# Processing Record 8 of Set 8 | maumere
# Processing Record 9 of Set 8 | alyangula
# Processing Record 10 of Set 8 | maldonado
# Processing Record 11 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 8 | hilo
# Processing Record 13 of Set 8 | izhmorskiy
# Processing Record 14 of Set 8 | magdagachi
# Processing Record 15 of Set 8 | hamilton
# Processing Record 16 of Set 8 | beloha
# Processing Record 17 of Set 8 | westport
# Processing Record 18 of Set 8 | konstantinovka
# Processing Record 19 of Set 8 | nha trang
# Processing Record 20 of Set 8 | port shepstone
# Processing Record 21 of Set 8 | upernavik
# Processing Record 22 of Set 8 | bontang
# Processing Record 23 of Set 8 | betioky
# Processing Record 24 of Set 8 | nawabganj
# Processing Record 25 of Set 8 | morondava
# Processing Record 26 of Set 8 | ambilobe
# Processing Record 27 of Set 8 | zhanaozen
# Processing Record 28 of Set 8 | ishcherskaya
# Processing Record 29 of Set 8 | eyl
# Processing Record 30 of Set 8 | tongliao
# Processing Record 31 of Set 8 | maragogi
# Processing Record 32 of Set 8 | daru
# Processing Record 33 of Set 8 | thanh hoa
# Processing Record 34 of Set 8 | gigmoto
# Processing Record 35 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | fuerte olimpo
# Processing Record 38 of Set 8 | vysokogornyy
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | misratah
# Processing Record 41 of Set 8 | peru
# Processing Record 42 of Set 8 | villa carlos paz
# Processing Record 43 of Set 8 | bafq
# Processing Record 44 of Set 8 | ferrol
# Processing Record 45 of Set 8 | bayir
# Processing Record 46 of Set 8 | tegh
# Processing Record 47 of Set 8 | surgut
# Processing Record 48 of Set 8 | polaniec
# Processing Record 49 of Set 8 | port moresby
# Processing Record 50 of Set 8 | cururupu
# Processing Record 1 of Set 9 | raudeberg
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | nyurba
# Processing Record 4 of Set 9 | paralimni
# Processing Record 5 of Set 9 | price
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | itarema
# Processing Record 8 of Set 9 | bograd
# Processing Record 9 of Set 9 | naifaru
# Processing Record 10 of Set 9 | romanovo
# Processing Record 11 of Set 9 | gao
# Processing Record 12 of Set 9 | hoquiam
# Processing Record 13 of Set 9 | porto walter
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | sao raimundo das mangabeiras
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | varkkallai
# Processing Record 18 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | promyshlennovskiy
# Processing Record 20 of Set 9 | general roca
# Processing Record 21 of Set 9 | bagrami
# Processing Record 22 of Set 9 | camopi
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | ust-kulom
# Processing Record 25 of Set 9 | maniitsoq
# Processing Record 26 of Set 9 | pontianak
# Processing Record 27 of Set 9 | sisimiut
# Processing Record 28 of Set 9 | ust-tsilma
# Processing Record 29 of Set 9 | taoudenni
# Processing Record 30 of Set 9 | malkangiri
# Processing Record 31 of Set 9 | shelburne
# Processing Record 32 of Set 9 | matara
# Processing Record 33 of Set 9 | hambantota
# Processing Record 34 of Set 9 | mimoso do sul
# Processing Record 35 of Set 9 | flinders
# Processing Record 36 of Set 9 | khurda
# Processing Record 37 of Set 9 | galle
# Processing Record 38 of Set 9 | poum
# Processing Record 39 of Set 9 | upington
# Processing Record 40 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 9 | palmira
# Processing Record 42 of Set 9 | pacific grove
# Processing Record 43 of Set 9 | iramuco
# Processing Record 44 of Set 9 | hirara
# Processing Record 45 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | verkhoyansk
# Processing Record 47 of Set 9 | kamyaran
# Processing Record 48 of Set 9 | cap malheureux
# Processing Record 49 of Set 9 | ituporanga
# Processing Record 50 of Set 9 | coquimbo
# Processing Record 1 of Set 10 | chimbote
# Processing Record 2 of Set 10 | mugur-aksy
# Processing Record 3 of Set 10 | prado
# Processing Record 4 of Set 10 | erzin
# Processing Record 5 of Set 10 | faya
# Processing Record 6 of Set 10 | sessa aurunca
# Processing Record 7 of Set 10 | kununurra
# Processing Record 8 of Set 10 | cidreira
# Processing Record 9 of Set 10 | liberal
# Processing Record 10 of Set 10 | uncia
# Processing Record 11 of Set 10 | mareeba
# Processing Record 12 of Set 10 | sitka
# Processing Record 13 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 10 | burnie
# Processing Record 15 of Set 10 | birjand
# Processing Record 16 of Set 10 | tomatlan
# Processing Record 17 of Set 10 | burns lake
# Processing Record 18 of Set 10 | lipin bor
# Processing Record 19 of Set 10 | nhlangano
# Processing Record 20 of Set 10 | kongolo
# Processing Record 21 of Set 10 | nioki
# Processing Record 22 of Set 10 | tanout
# Processing Record 23 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 10 | acajutla
# Processing Record 25 of Set 10 | bandiagara
# Processing Record 26 of Set 10 | waipawa
# Processing Record 27 of Set 10 | aginskoye
# Processing Record 28 of Set 10 | khilok
# Processing Record 29 of Set 10 | piopio
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | gushikawa
# Processing Record 32 of Set 10 | bilma
# Processing Record 33 of Set 10 | qasigiannguit
# Processing Record 34 of Set 10 | sao jose da coroa grande
# Processing Record 35 of Set 10 | ugoofaaru
# Processing Record 36 of Set 10 | bosaso
# Processing Record 37 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 10 | asau
# Processing Record 39 of Set 10 | markova
# Processing Record 40 of Set 10 | nuuk
# Processing Record 41 of Set 10 | camacupa
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | rameshki
# Processing Record 44 of Set 10 | businga
# Processing Record 45 of Set 10 | itarantim
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | shirokiy
# Processing Record 48 of Set 10 | olivet
# Processing Record 49 of Set 10 | abdanan
# Processing Record 50 of Set 10 | ocos
# Processing Record 1 of Set 11 | kalisz
# Processing Record 2 of Set 11 | ginir
# Processing Record 3 of Set 11 | marau
# Processing Record 4 of Set 11 | jequie
# Processing Record 5 of Set 11 | san cristobal
# Processing Record 6 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 11 | green river
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | shamkhal
# Processing Record 10 of Set 11 | perg
# Processing Record 11 of Set 11 | pavlodar
# Processing Record 12 of Set 11 | ukhta
# Processing Record 13 of Set 11 | sovetsk
# Processing Record 14 of Set 11 | san bernardo
# Processing Record 15 of Set 11 | ust-omchug
# Processing Record 16 of Set 11 | praia
# Processing Record 17 of Set 11 | the valley
# Processing Record 18 of Set 11 | yagodnoye
# Processing Record 19 of Set 11 | husavik
# Processing Record 20 of Set 11 | lazaro cardenas
# Processing Record 21 of Set 11 | safakulevo
# Processing Record 22 of Set 11 | ponoka
# Processing Record 23 of Set 11 | severo-kurilsk
# Processing Record 24 of Set 11 | nome
# Processing Record 25 of Set 11 | barquisimeto
# Processing Record 26 of Set 11 | kahului
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | zhicheng
# Processing Record 31 of Set 11 | livingston
# Processing Record 32 of Set 11 | anadyr
# Processing Record 33 of Set 11 | makakilo city
# Processing Record 34 of Set 11 | san luis
# Processing Record 35 of Set 11 | santa rosa
# Processing Record 36 of Set 11 | portree
# Processing Record 37 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 11 | san rafael
# Processing Record 39 of Set 11 | fort nelson
# Processing Record 40 of Set 11 | sao miguel do araguaia
# Processing Record 41 of Set 11 | arman
# Processing Record 42 of Set 11 | iquitos
# Processing Record 43 of Set 11 | maningrida
# Processing Record 44 of Set 11 | cayenne
# Processing Record 45 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 11 | halifax
# Processing Record 47 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 11 | saint-joseph
# Processing Record 49 of Set 11 | balakhninskiy
# Processing Record 50 of Set 11 | rock springs
# Processing Record 1 of Set 12 | coahuayana
# Processing Record 2 of Set 12 | bonnyville
# Processing Record 3 of Set 12 | sakakah
# Processing Record 4 of Set 12 | kupang
# Processing Record 5 of Set 12 | la asuncion
# Processing Record 6 of Set 12 | malatya
# Processing Record 7 of Set 12 | longyearbyen
# Processing Record 8 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 12 | ardakan
# Processing Record 10 of Set 12 | punta alta
# Processing Record 11 of Set 12 | manambrag
# City not found. Skipping...
# Processing Record 12 of Set 12 | budureasa
# Processing Record 13 of Set 12 | seoul
# Processing Record 14 of Set 12 | moerai
# Processing Record 15 of Set 12 | valparaiso
# Processing Record 16 of Set 12 | hirna
# Processing Record 17 of Set 12 | montague
# Processing Record 18 of Set 12 | gobabis
# Processing Record 19 of Set 12 | te anau
# Processing Record 20 of Set 12 | tucuman
# Processing Record 21 of Set 12 | smidovich
# Processing Record 22 of Set 12 | timberlake
# Processing Record 23 of Set 12 | pimentel
# Processing Record 24 of Set 12 | sungaipenuh
# Processing Record 25 of Set 12 | paamiut
# Processing Record 26 of Set 12 | mortka
# Processing Record 27 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 12 | cruzeiro do sul
# Processing Record 29 of Set 12 | srivardhan
# Processing Record 30 of Set 12 | rabo de peixe
# Processing Record 31 of Set 12 | karasburg
# Processing Record 32 of Set 12 | karpogory
# Processing Record 33 of Set 12 | goundam
# Processing Record 34 of Set 12 | sioux lookout
# Processing Record 35 of Set 12 | yeniseysk
# Processing Record 36 of Set 12 | benghazi
# Processing Record 37 of Set 12 | rio gallegos
# Processing Record 38 of Set 12 | kananga
# Processing Record 39 of Set 12 | weatherford
# Processing Record 40 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 41 of Set 12 | uppsala
# Processing Record 42 of Set 12 | nambucca heads
# Processing Record 43 of Set 12 | bridlington
# Processing Record 44 of Set 12 | kibre mengist
# Processing Record 45 of Set 12 | yamada
# Processing Record 46 of Set 12 | sorland
# Processing Record 47 of Set 12 | lufilufi
# Processing Record 48 of Set 12 | phuthaditjhaba
# Processing Record 49 of Set 12 | novobirilyussy
# Processing Record 50 of Set 12 | ohara
# Processing Record 1 of Set 13 | taltal
# Processing Record 2 of Set 13 | puerto escondido
# Processing Record 3 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | antibes
# Processing Record 5 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 6 of Set 13 | gort
# Processing Record 7 of Set 13 | ust-maya
# Processing Record 8 of Set 13 | marsabit
# Processing Record 9 of Set 13 | jorpeland
# Processing Record 10 of Set 13 | potsdam
# Processing Record 11 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 13 | luganville
# Processing Record 13 of Set 13 | iguape
# Processing Record 14 of Set 13 | almeria
# Processing Record 15 of Set 13 | ponta delgada
# Processing Record 16 of Set 13 | santa cruz
# Processing Record 17 of Set 13 | kinango
# Processing Record 18 of Set 13 | pangkalanbuun
# Processing Record 19 of Set 13 | menongue
# Processing Record 20 of Set 13 | bubaque
# Processing Record 21 of Set 13 | kuching
# Processing Record 22 of Set 13 | boguchany
# Processing Record 23 of Set 13 | cabedelo
# Processing Record 24 of Set 13 | koutsouras
# Processing Record 25 of Set 13 | tornio
# Processing Record 26 of Set 13 | minab
# Processing Record 27 of Set 13 | howard springs
# Processing Record 28 of Set 13 | teya
# Processing Record 29 of Set 13 | bryanka
# Processing Record 30 of Set 13 | bodden town
# Processing Record 31 of Set 13 | sydney
# Processing Record 32 of Set 13 | luis correia
# Processing Record 33 of Set 13 | cullman
# Processing Record 34 of Set 13 | umea
# Processing Record 35 of Set 13 | dhidhdhoo
# Processing Record 36 of Set 13 | prince rupert
# Processing Record 37 of Set 13 | jiexiu
# Processing Record 38 of Set 13 | presidente olegario
# Processing Record 39 of Set 13 | barra do garcas
# Processing Record 40 of Set 13 | kingsport
# Processing Record 41 of Set 13 | mangai
# Processing Record 42 of Set 13 | kijang
# Processing Record 43 of Set 13 | nizwa
# Processing Record 44 of Set 13 | eregli
# Processing Record 45 of Set 13 | tharrawaddy
# City not found. Skipping...
# Processing Record 46 of Set 13 | ningan
# City not found. Skipping...
# Processing Record 47 of Set 13 | mercedes
# Processing Record 48 of Set 13 | gilazi
# City not found. Skipping...
# Processing Record 49 of Set 13 | muscat
# Processing Record 50 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 3 of Set 14 | lowicz
# Processing Record 4 of Set 14 | gornopravdinsk
# Processing Record 5 of Set 14 | pueblo
# Processing Record 6 of Set 14 | masvingo
# Processing Record 7 of Set 14 | acari
# Processing Record 8 of Set 14 | oranjemund
# Processing Record 9 of Set 14 | hurghada
# Processing Record 10 of Set 14 | khorixas
# Processing Record 11 of Set 14 | lobito
# Processing Record 12 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 13 of Set 14 | thaton
# Processing Record 14 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 14 | costinesti
# Processing Record 16 of Set 14 | byron bay
# Processing Record 17 of Set 14 | haapsalu
# Processing Record 18 of Set 14 | aleksandrov gay
# Processing Record 19 of Set 14 | san andres
# Processing Record 20 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 21 of Set 14 | jacareacanga
# Processing Record 22 of Set 14 | le port
# Processing Record 23 of Set 14 | ada
# Processing Record 24 of Set 14 | tiarei
# Processing Record 25 of Set 14 | tazovskiy
# Processing Record 26 of Set 14 | maarianhamina
# Processing Record 27 of Set 14 | kribi
# Processing Record 28 of Set 14 | loa janan
# Processing Record 29 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 30 of Set 14 | finca cincuenta y uno
# City not found. Skipping...
# Processing Record 31 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 34 of Set 14 | los llanos de aridane
# Processing Record 35 of Set 14 | saint anthony
# Processing Record 36 of Set 14 | elliot lake
# Processing Record 37 of Set 14 | misheronskiy
# Processing Record 38 of Set 14 | mecca
# Processing Record 39 of Set 14 | macau
# Processing Record 40 of Set 14 | thap than
# Processing Record 41 of Set 14 | gombong
# Processing Record 42 of Set 14 | kingaroy
# Processing Record 43 of Set 14 | acarau
# Processing Record 44 of Set 14 | celestun
# Processing Record 45 of Set 14 | kindu
# Processing Record 46 of Set 14 | bronnoysund
# Processing Record 47 of Set 14 | kudahuvadhoo
# Processing Record 48 of Set 14 | nhulunbuy
# Processing Record 49 of Set 14 | bojnurd
# Processing Record 50 of Set 14 | tiznit
# Processing Record 1 of Set 15 | ardahan
# Processing Record 2 of Set 15 | riyadh
# Processing Record 3 of Set 15 | sonoita
# Processing Record 4 of Set 15 | warrnambool
# Processing Record 5 of Set 15 | sfantu gheorghe
# Processing Record 6 of Set 15 | talara
# Processing Record 7 of Set 15 | velsk
# Processing Record 8 of Set 15 | gorom-gorom
# Processing Record 9 of Set 15 | palora
# Processing Record 10 of Set 15 | delta del tigre
# Processing Record 11 of Set 15 | listvyanka
# Processing Record 12 of Set 15 | perth
# Processing Record 13 of Set 15 | sri aman
# Processing Record 14 of Set 15 | yatou
# Processing Record 15 of Set 15 | qaqortoq
# Processing Record 16 of Set 15 | peniche
# Processing Record 17 of Set 15 | sanchursk
# Processing Record 18 of Set 15 | denpasar
# Processing Record 19 of Set 15 | hirado
# Processing Record 20 of Set 15 | vaitape
# Processing Record 21 of Set 15 | takoradi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bredasdorp -34.5322   20.0403     60.28        82          89
# 1            Hobart -42.8794  147.3294     68.27        78          75
# 2      Constitucion -35.3333  -72.4167     57.36        92           3
# 3      Punta Arenas -53.1500  -70.9167     68.11        22           0
# 4             Gazli  40.1333   63.4500     34.74        75          45
# 5       Kotelnikovo  47.6317   43.1461     29.34        97         100
# 6  Valenca Do Piaui  -6.4075  -41.7456     70.18        96         100
# 7       East London -33.0153   27.9116     66.96        78           0
# 8              Okha  53.5739  142.9478    -10.21        90           5
# 9              Lima -12.0432  -77.0282     70.39        80          40
#
#    Wind Speed Country                 Date Current Description
# 0        4.61      ZA  2022-01-29 00:54:08     overcast clouds
# 1       13.80      AU  2022-01-29 00:52:51       broken clouds
# 2        5.68      CL  2022-01-29 00:54:08           clear sky
# 3        8.05      CL  2022-01-29 00:54:09           clear sky
# 4       11.68      UZ  2022-01-29 00:54:09    scattered clouds
# 5       13.91      RU  2022-01-29 00:54:09          light snow
# 6        5.26      BR  2022-01-29 00:54:10     overcast clouds
# 7       10.63      ZA  2022-01-29 00:54:10           clear sky
# 8       12.82      RU  2022-01-29 00:54:10           clear sky
# 9       13.80      PE  2022-01-29 00:54:11    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
